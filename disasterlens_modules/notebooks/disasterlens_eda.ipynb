# %% [markdown]
# # DisasterLens dataset EDA
#
# This notebook delegates reproducible analysis to `run_eda.py`. The script writes aggregate plots and does not display raw dataset records.

# %%
# %run run_eda.py
